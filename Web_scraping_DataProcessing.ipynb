# %% [markdown]
# # Web Scraping Project
# ### Introduction
#
# This project goal is to scrape a certain e-commerce website (in this case bukalapak.com) using python with some packages; `Selenium`, `BeautifulSoup` and `pandas`.
#
# `Selenium` will be used to do the automation of webdriver.
# <br>`BeautifulSoup` will be used to parse the html.
# <br>`pandas` will be used for the data manipulation.
#
# Some information that will be scraped are:
#     - product_name = name of the product
#     - product_category = category of the product
#     - rating = product rating out of 5 stars
#     - store_name = name of the store including the city of the store
#     - price = price of the product
#
# Data that will be collected consists of 5 different categories (lari, renang, badminton, tenis, pancing) with at least 500 items in each category.

# %%
# Install the following packages for the first time use only
pip install selenium
pip install bs4
# Out:
# Collecting bs4
#   Using cached https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: beautifulsoup4 in c:\users\arsil\anaconda3\lib\site-packages (from bs4) (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\arsil\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (1.8)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Arsil\AppData\Local\pip\Cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#1. Import Packages needed for the project
import selenium #for automation
from selenium import webdriver #for canvas navigator
from selenium.webdriver.common.by import By #for finding elements
from selenium.webdriver.support.ui import WebDriverWait #to make the webdriver wait
from bs4 import BeautifulSoup #to make the scraping easier
import pandas as pd #to manipulate data

# %%
#2. Setting up the driver

#Path of the webdriver
path = "C:/Program Files (x86)/chromedriver.exe"

#Setting Webdriver
driver = webdriver.Chrome(executable_path = path)
# Out:
# C:\Users\Arsil\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   import sys

# %%
#3. Setting up the automated surf for web driving

wait = driver.implicitly_wait(10) #set the driver to wait

#define the website target and category target
website_address = "https://www.bukalapak.com/c/olahraga/"
subcategory = ['lari', 'renang', 'badminton', 'tenis', 'pancing']

#define the container for data storing
products = []

#defining the function to scrape surfed data to each container
def scrape_func(i):
    results = [] #container for the scraped data
    
    #to set the inside of the html
    html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
    #parsing the html
    soup = BeautifulSoup(html,"html.parser")
    
    #iteration for scraping every product displayed in the website
    for product in soup.find_all('div', class_= 'bl-product-card__description') :
        result = product.get_text().split("\n") #soup is scraping in JSON format, so get_text is used to scrape the text format
        result.append(i) #add the scraped data to the container
        results.append(result)
    return results #return the result of scraped data

#iteration for pagination on webdriver
for i in subcategory: #iteration for the subcategory
    for j in range(40): #iteration for pages needed to fulfil the minimum desired data
        
        '''
        because the website structure for the pagination is different between the first page and
        the next one, I use 2 conditions for the pagination
        '''
        if j > 0 : #for pagination when page number is greater than 1
            driver.get(website_address+i+'?page='+str(j+1))
            wait
            driver.execute_script("window.scrollTo(0, 700)")
            product = scrape_func(i)
            for k in product :
                products.append(k)
        else :  #for pagination of the first page
            driver.get(website_address+i+'?')
            wait
            driver.execute_script("window.scrollTo(0, 700)")
            product = scrape_func(i)
            for k in product :
                products.append(k)

#After the scraping is finished, close the webdriver to save memories and power            
driver.quit()
# Out:
# C:\Users\Arsil\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   if __name__ == '__main__':

# %%
#explore the data scraped
products[:5]
# Out:
# [['',
#   '            Tissue Handuk Mini Permen Travelling Liburan Kompress Towel Portable',
#   '             ',
#   '          Rp600',
#   '            ',
#   '              4.9',
#   '              ',
#   '          Terjual 19912',
#   '         ',
#   '          Depok',
#   '         ',
#   '            LBS OFFICIAL STORE',
#   '            ',
#   '            108rb Feedback Positif',
#   '           ',
#   'lari'],
#  ['',
#   '            celana mizuno voli celana badminton',
#   '             ',
#   '          Rp23.800',
#   '            ',
#   '              4.9',
#   '              ',
#   '          Terjual 16296',
#   '         ',
#   '          Jakarta Barat',
#   '         ',
#   '            IZDIHAAR SPORT',
#   '            ',
#   '            19rb Feedback Positif',
#   '           ',
#   'lari'],
#  ['',
#   '            Sepatu Sneaker Pria Wanita Slip On Sepatu Sport Olahraga Lari Running Jogging Sepatu Casual Cowok Cewek Terbaru Terlaris',
#   '             ',
#   '          Rp145.800',
#   '            ',
#   '              4.9',
#   '              ',
#   '          Terjual 8496',
#   '         ',
#   '          Bandung',
#   '         ',
#   '            Saudagar Muda',
#   '            ',
#   '            2rb Feedback Positif',
#   '           ',
#   'lari'],
#  ['',
#   '            celana voli fullprint kolor voly printing volleyball badminton',
#   '             ',
#   '          Rp45.000',
#   '            ',
#   '              4.8',
#   '              ',
#   '          Terjual 7944',
#   '         ',
#   '          Jakarta Barat',
#   '         ',
#   '            IZDIHAAR SPORT',
#   '            ',
#   '            19rb Feedback Positif',
#   '           ',
#   'lari'],
#  ['',
#   '            Penyangga Punggung Shoulder Back Support Belt Posture Corrector Korset - Hitam XL',
#   '             ',
#   '          Rp45.000',
#   '            ',
#   '              4.7',
#   '              ',
#   '          Terjual 7887',
#   '         ',
#   '          Depok',
#   '         ',
#   '            LBS OFFICIAL STORE',
#   '            ',
#   '            108rb Feedback Positif',
#   '           ',
#   'lari']]

# %% [markdown]
# The result from scraping is very 'dirty'. It has many information that we don't need, so we have to do some cleaning dor the data to make it easier for further analysis.

# %%
#4. Data Cleaning

#preparing the container for the cleaning result
products_cleaned = []

#Iteration for data cleaning
for product in products: 
    container = [] #reusable container for each product description
    for item in product:
        item = item.strip() #cleaning the whitespace
        if item != '' and item != 'Grosir' and item.startswith('Terjual') != True and item.endswith('Feedback Positif') != True and item.endswith('Feedback Negatif') != True :
            '''
            the if statement above is cleaning the excess newline, "Grosir" information
            sold item count, and item's feedback count
            '''
            container.append(item) #collecting the cleaned item
    if container[2].startswith('Rp') == True and container[3].endswith('%') == True:
        '''
        the if statement above is cleaning the discount information that display the
        price before discount and the value of the discount
        '''
        container.pop(2) #delete the price-before-discount data
        container.pop(2) #delete the discount value
    elif container[1].startswith('Rp') != True:
        #this statement clean the remaining abnormal data
        container[0] = container[0]+container[1]
        container.pop(1)
    elif len(container[2]) > 3:
        container.insert(2, "no rating")
    
    container[1] = container[1].replace("Rp", "") #Replacing the "Rp" so that we can turn it into int
    container[1] = container[1].replace(".","") #Replacing the "." so that we can turn it into int
    container[1] = int(container[1]) #changing the data type of the string into int
    
    if len(container[2]) == 3 : #changing the data that has rating into float
        container[2] = float(container[2])
    products_cleaned.append(container)
    
products_cleaned
# Out:
# [['Tissue Handuk Mini Permen Travelling Liburan Kompress Towel Portable',
#   600,
#   4.9,
#   'Depok',
#   'LBS OFFICIAL STORE',
#   'lari'],
#  ['celana mizuno voli celana badminton',
#   23800,
#   4.9,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Sepatu Sneaker Pria Wanita Slip On Sepatu Sport Olahraga Lari Running Jogging Sepatu Casual Cowok Cewek Terbaru Terlaris',
#   145800,
#   4.9,
#   'Bandung',
#   'Saudagar Muda',
#   'lari'],
#  ['celana voli fullprint kolor voly printing volleyball badminton',
#   45000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Penyangga Punggung Shoulder Back Support Belt Posture Corrector Korset - Hitam XL',
#   45000,
#   4.7,
#   'Depok',
#   'LBS OFFICIAL STORE',
#   'lari'],
#  ['Legging Panjang Baselayer Ukuran Standar dan Jumbo',
#   18000,
#   4.8,
#   'Depok',
#   'Leggingid official',
#   'lari'],
#  ['Tali medali ORIGINAL Tali medali sleret Merah Putih dan Hijau Putih',
#   1650,
#   '5',
#   'Jakarta Utara',
#   'Bintang Jaya',
#   'lari'],
#  ['CONE / CONES KERUCUT LENTUR UNTUK LATIHAN OLAHRAGA',
#   4900,
#   4.8,
#   'Jakarta Barat',
#   'ids sport',
#   'lari'],
#  ['Celana Dryfit Celana Jogging Lari Basket Celana Olahraga Celana Santai Celana Pendek Pria',
#   45000,
#   '5',
#   'Jakarta Barat',
#   'Marge Shop',
#   'lari'],
#  ['Sepatu Pria Badminton Hipzo M 042 Original Olahraga Lari Senam Pria Sneakers',
#   99000,
#   4.9,
#   'Kab. Mojokerto',
#   'Hipzo Official Shop',
#   'lari'],
#  ['celana voli fullprinting kolor volly printing terbaru bahan tebal',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['jas hujan reebok murah', 44000, 4.7, 'Bandung', 'ujang77', 'lari'],
#  ['Botol Minum Plastik Olahraga Sepeda Tour De France Drink Bottle 750ml',
#   15000,
#   4.7,
#   'Depok',
#   'LBS OFFICIAL STORE',
#   'lari'],
#  ['celana voli full printing kolor proliga printing celana pendek volley ball',
#   45000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['CELANA BADMINTON LINING KOLOR BADMINTON CELANA BULUTANGKIS',
#   25000,
#   'no rating',
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana voli kolor volly logo club proliga 2020',
#   24900,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana voli fullprinting kolor poly voly volley bahan tebal IZDIHAAR SHOP',
#   45000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Legging Sport', 22000, 4.8, 'Depok', 'Leggingid official', 'lari'],
#  ['celana voli kolor volly polos futsal basket tenis badminton',
#   20000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Pelindung Gusi Mouth Guard Gum Shield Teeth Protector Karate Boxing',
#   7500,
#   4.8,
#   'Depok',
#   'LBS OFFICIAL STORE',
#   'lari'],
#  ['SALTSTICK salt stick PLUS CAFFEINE kafein',
#   10500,
#   4.9,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['celana voli full printing kolor volly printing bahan tebal grosir eceran',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana voli full printing bahan tebal kolor voly',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana senam wanita legging celana olahraga wanita',
#   25000,
#   4.8,
#   'Depok',
#   'Leggingid official',
#   'lari'],
#  ['celana voli full printing bahan tebal kolor volly printing',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana voli printing kolor fullprinting tebal',
#   45000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana voli full printing logo mizuno asic kolor badminton',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['CELANA TRAINING JOGGER PENDEK PRODUK TERLARIS - Navy',
#   65000,
#   4.7,
#   'Jakarta Barat',
#   'EMOLINE 8',
#   'lari'],
#  ['Saddle Shoes / Shoes Tree / Catokan Sepatu / Penyangga Sepatu',
#   17000,
#   4.6,
#   'Jakarta Timur',
#   'jakartakinesio',
#   'lari'],
#  ['Sepatu Sketcher Slip on go walk sol black sepatu pria grade ori',
#   145000,
#   4.6,
#   'Jakarta Barat',
#   'claressa cloth',
#   'lari'],
#  ['running belt waterproof - tas pinggang olahraga - tas olahraga - go belt - aksesoris senam',
#   21000,
#   4.8,
#   'Jakarta Barat',
#   'navy shops',
#   'lari'],
#  ['Jogger Pendek Training Polos Celana Olahraga Gym Fitness - Navy',
#   55000,
#   4.8,
#   'Jakarta Barat',
#   'EMOLINE 8',
#   'lari'],
#  ['celana fullprinting voli badminton kolor voly',
#   45000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Original Aolikes Sport Deker Gym Pelindung Lutut Adlikes Knee Patella Support Strap Tendon Protector',
#   70000,
#   4.8,
#   'Depok',
#   'DEPOKSITE',
#   'lari'],
#  ['kolor futsal voli badminto celana pendek olahraga merah',
#   24000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['new running sport bag - fitness gym sepeda tas pinggang Waterproof olahraga lari',
#   25000,
#   4.7,
#   'Jakarta Barat',
#   'BABAMU JAYA',
#   'lari'],
#  ['Universal Sports Armband Case untuk android dan iphone arm band',
#   25000,
#   4.4,
#   'Jakarta Selatan',
#   'selaza acc',
#   'lari'],
#  ['CELANA FULPRINTING VOLI KOLOR VOLLY PRINTING',
#   45000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana olahraga wanita celana senam',
#   30000,
#   4.8,
#   'Depok',
#   'Leggingid official',
#   'lari'],
#  ['BOTOL SPORT ALUMINIUM 750 ML',
#   30000,
#   4.7,
#   'Jakarta Utara',
#   'DWIJAYA  STORE',
#   'lari'],
#  ['Tas Ikat Pinggang Sabuk Olahraga Lari / Double Pocket Belt Korea Running Sport Gym Waterproof / Tas Multi Fungsi Modern',
#   15000,
#   4.3,
#   'Surabaya',
#   'baranguniku',
#   'lari'],
#  ['Tas Jogging Lengan Tas Lari HP Running Sport Arm Band Case Tas HP GYM',
#   14900,
#   4.6,
#   'Jakarta Barat',
#   'ViralShop87',
#   'lari'],
#  ['TAS PINGGANG SPORT KEREN !!', 24000, 4.8, 'Jakarta Utara', 'METTO', 'lari'],
#  ['Joger Sport Anak-Motif Polos',
#   14500,
#   4.8,
#   'Bandung',
#   'Hafiya KIds Shop',
#   'lari'],
#  ['celana pendek short pants unisex pria wanita murah buat gym futsal badminton',
#   32000,
#   4.5,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['BARU !!! RUNNING BIB RACE HOLDER / PENGIKAT NOMOR DADA SAAT LOMBA LARI',
#   10000,
#   4.9,
#   'Bandung',
#   'Secret Adventure',
#   'lari'],
#  ['Shorts Pants Celana Olahraga Pendek Motif Api Kantong RESLETING UA01',
#   65000,
#   4.7,
#   'Bandung',
#   'simplezone',
#   'lari'],
#  ['Tas Pinggang Army Dompet Sarung HP ARMY Tas Gadget Kecil Militer',
#   23900,
#   4.7,
#   'Jakarta Barat',
#   'ViralShop87',
#   'lari'],
#  ['celana pendek pria wanita sepeda badminton running gym bahan adem murah',
#   7000,
#   4.7,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['CELANA JOGGER TRAINING JUMBO XXL WANITA PRIA YOGA GYM SPORT PRINTING',
#   75000,
#   4.4,
#   'Bandung',
#   'RaiderJacket',
#   'lari'],
#  ['Jaket Sport Running Nike',
#   55000,
#   4.1,
#   'Kab. Bandung',
#   'FRANKIES SPORT',
#   'lari'],
#  ['Cone Mangkok latihan olahraga sport bola slalom skate fitness',
#   4698,
#   '5',
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'lari'],
#  ['celana panjang jogger trening olahraga pria wanita gym running fitnes senam yoga polos katun dingin',
#   90000,
#   4.8,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['HT01 Sepatu Running Lari Pria Cowok Size 39-44 Sepatu Sneaker Olahraga Fitness Import Sepatu Pria Casual Sport Santai Murah',
#   138000,
#   4.8,
#   'Tangerang Selatan',
#   'HARISGO STORE',
#   'lari'],
#  ['celana voli badminton futsal single printing',
#   27500,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['HT02 Sepatu Sport Olahraga Size 39-44 Hitam Orange Pria Sepatu Running Lari Cowok Sepatu Slip On Santai Kanvas Sol Karet Untuk Sekolah Kuliah',
#   149900,
#   4.8,
#   'Tangerang Selatan',
#   'HARISGO STORE',
#   'lari'],
#  ['Elite Road ID / Black Road ID / Sport ID / Gelang Kecemasan Toko883',
#   210000,
#   4.8,
#   'Jakarta Utara',
#   'toko883',
#   'lari'],
#  ['sepatu outdoor sepatu rafting sepatu sepeda sepatu gowes sepatu gym sepatu fitnes sepatu pantai sepatu Senorkeling',
#   189000,
#   4.7,
#   'Jakarta Barat',
#   'OKE Mart',
#   'lari'],
#  ['Spibelt Bag Tas Pinggang Tas Lari Waist Running Bag Tas Olahraga',
#   30000,
#   4.7,
#   'Jakarta Utara',
#   'BLOSSOM JAYA',
#   'lari'],
#  ['Jaket Reebok Sport Multifungsi Sauna (Hitam) BEST CHOICE',
#   41000,
#   4.7,
#   'Kab. Bandung',
#   'BarangBagus Store',
#   'lari'],
#  ['Celana Training Misti Ukur Besar',
#   19500,
#   4.3,
#   'Solo',
#   'Grosiran Pasar Klewer',
#   'lari'],
#  ['SePatuAdidas', 80000, 4.3, 'Kab. Bandung', 'rVn Footwear', 'lari'],
#  ['Diadora sepatu lari cowokk original asli termurah',
#   349000,
#   4.7,
#   'Solo',
#   'TRANS SPORTS',
#   'lari'],
#  ['celana olahraga wanita sport',
#   30000,
#   4.8,
#   'Depok',
#   'Leggingid official',
#   'lari'],
#  ['BH Bra Cendana', 9500, 4.4, 'Solo', 'Grosiran Pasar Klewer', 'lari'],
#  ['sepatuadidas', 420000, 4.1, 'Kab. Bandung', 'rVn Footwear', 'lari'],
#  ['celana olahraga lari Tactico',
#   100000,
#   4.8,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Gelang Kecemasan Slim / Slim Road ID / Safe ID Slim / ID tag Slim / Road ID Slim',
#   155000,
#   4.9,
#   'Jakarta Utara',
#   'toko883',
#   'lari'],
#  ['Sepatu Sport Badminton Airquila Black Hitam Original',
#   74000,
#   4.8,
#   'Solo',
#   'Veloci Shop',
#   'lari'],
#  ['Sepatu Running Lari Nike Revolution 5 Black White BQ3204-002 Original',
#   799000,
#   4.9,
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['Tas Pinggang Offroad Trail Adventure Running Model Bladder',
#   175000,
#   4.8,
#   'Bandung',
#   'NugrossMX',
#   'lari'],
#  ['Celana Training 01', 17500, 4.2, 'Solo', 'Grosiran Pasar Klewer', 'lari'],
#  ['celana lari tactico proven black',
#   100000,
#   4.8,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['celana olahraga celana panjang celana trening celana joger celana futsal celana santai',
#   70000,
#   4.6,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['Geoff Max Athletica - AT 693 Black White Shoes',
#   375000,
#   4.9,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['PROMO LEBARAN Adidas Cosmic Boost sepatu sport import',
#   259000,
#   '4',
#   'Bandung Barat',
#   'ADRS FOOTWEAR PROJECT',
#   'lari'],
#  ['karet Karambol Mentah', 34000, 4.8, 'Jakarta Barat', 'Globalsport', 'lari'],
#  ['Stopwatch 6167  -  XL.010 stop watch',
#   17000,
#   4.8,
#   'Jakarta Pusat',
#   'dbestcompushop',
#   'lari'],
#  ['lock laces - lace tali sepatu serut elastis',
#   9000,
#   4.8,
#   'Jakarta Utara',
#   'dpeakoutdoor',
#   'lari'],
#  ['Sepatu pria running REEBOK warna hitam bahan kain',
#   100000,
#   4.6,
#   'Mojokerto',
#   'Neas16_Shop',
#   'lari'],
#  ['celana pendek short pants trening sepeda futsal badminton running gym bahan parasut murah',
#   35000,
#   4.7,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['Nineten 910 Socks FUKA Quarter Hitam-Putih-Biru',
#   20000,
#   4.8,
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Aonijie Waist Bag E848T - Tas Pinggang lari Sepeda Gym - BLACK',
#   75000,
#   4.9,
#   'Jakarta Utara',
#   'Aonijie Indonesia',
#   'lari'],
#  ['sepatu running diadora ori terbaru asli original termurah',
#   349000,
#   4.8,
#   'Solo',
#   'TRANS SPORTS',
#   'lari'],
#  ['Celana Sport Legging Import Wanita 3 4 7 8 Dot Silver Celana Senam Celana Yoga Celana Gym Fitness',
#   159000,
#   4.7,
#   'Jakarta Barat',
#   'Zen Blossom',
#   'lari'],
#  ['Cone Kerucut latihan olahraga sport bola slalom skate fitness',
#   10440,
#   '5',
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'lari'],
#  ['PROMO SALE Waist Bag Running Belt Tas Pinggang Olaharaga Jogging Lari',
#   30000,
#   4.7,
#   'Tangerang',
#   'Techdoo',
#   'lari'],
#  ['SEPATU SNEAKERS RUNNING ORTUSEIGHT 100 ORIGINAL HARVARD Black White',
#   299000,
#   4.9,
#   'Jakarta Selatan',
#   'RANK Sports CLD',
#   'lari'],
#  ['celana pendek short pants wanita pria futsal gym running badminton futsal murah',
#   10000,
#   4.8,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['Sepatu Running Lari Nike Revolution 5 Black Anthracite BQ3204-001 Ori',
#   799000,
#   '5',
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['celana pendek short pants pria wanita gym sepeda futsal bahan parasit murah',
#   50000,
#   4.6,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['Dust plug cover charger garmin fr 935 vivoactive 3 fenix 5 5x',
#   10000,
#   4.9,
#   'Tangerang Selatan',
#   'TOKO DIANA',
#   'lari'],
#  ['COD Celana Pendek Quickdry Kolor - Celana Gunung Outdoor - Celana Trekking Hiking Camping',
#   45000,
#   4.7,
#   'Bekasi',
#   'bogabooindonesia',
#   'lari'],
#  ['celana panjang long pants pria wanita gym futsal senam zumba murah',
#   40000,
#   4.7,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['celana pendek short pants unisex pria wanita futsal gym running murah',
#   39000,
#   4.9,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['Penyangga Lutut Mussels Knee Booster Pads Spring Force Stabilizer 2 PCS ZLQ-001 Cedera Engsel Deker',
#   1017000,
#   '5',
#   'Jakarta Barat',
#   'Keys Store',
#   'lari'],
#  ['Tas Pinggang/ Waistbag/ Tas Lari',
#   125000,
#   4.8,
#   'Kab. Bandung',
#   'Reuma',
#   'lari'],
#  ['celana pendek short pants pria wanita gym futsal yoga renang sepeda badminton',
#   45900,
#   4.5,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['sepatuadidas', 130000, 4.2, 'Kab. Bandung', 'rVn Footwear', 'lari'],
#  ['Watch ID. Garmin ID. Pet ID Hitam. Road ID tuk jam tangan',
#   130000,
#   '5',
#   'Jakarta Utara',
#   'toko883',
#   'lari'],
#  ['celana panjang jogger trening premium olahraga senam zumba gym pria wanita polos bahan import',
#   185000,
#   4.7,
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['CELANA SEPEDA GOWES BUSA PADDING CELANA SEPEDA PRIA WANITA CELANA SEPEDA BALAP KETAT MTB',
#   55000,
#   4.8,
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'lari'],
#  ['Celana Jogger Pants Nike Panjang / Joger Pants Termurah',
#   55000,
#   4.7,
#   'Bandung',
#   'WANTOSHOP',
#   'lari'],
#  ['celana lari tactico', 100000, 4.9, 'Kab. Bandung', 'arm sport', 'lari'],
#  ['kolor voly full printing celana voli printing badminton futsal',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Celana senam rok wanita celana senam panjang wanita celana olahraga wanita celana joger legging',
#   140000,
#   'no rating',
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['CELANA JOGGER REEBOK PANJANG - SWEATPANTS - TRAINING REEBOK CLASSIC',
#   37900,
#   4.8,
#   'Bekasi',
#   'JSHOP JERSEY',
#   'lari'],
#  ['celana pendek short pants trening sontog sepeda futsal badminton running gym bahan paragon murah',
#   10000,
#   '4',
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['celana pendek short pants garis 2 samping wanita pria futsal gym running badminton futsal murah',
#   36990,
#   '5',
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['sepatu running diadora ori asli original termurah',
#   349000,
#   4.7,
#   'Solo',
#   'TRANS SPORTS',
#   'lari'],
#  ['celana pendek sport short pants wanita pria futsal gym running badminton futsal murah',
#   15000,
#   '5',
#   'Bandung',
#   'snprojectbdg',
#   'lari'],
#  ['Sepatu Sepeda Sepatu Pantai Sepatu Outdoor Sepatu Gym Fitness Sepatu Hiking Sepatu Rafting Sepatu Diving Sepatu Senorkeling',
#   210000,
#   4.8,
#   'Jakarta Barat',
#   'OKE Mart',
#   'lari'],
#  ['kolor voli printing celana volly fulprin',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['CELANA PENDEK PINNACLE HELIX NEW 2020 CELANA GUNUNG PENDEK UNTUK TRACKING QUICKDRY',
#   145000,
#   4.9,
#   'Sidoarjo',
#   'Omah Alas Adventure',
#   'lari'],
#  ['Elite SLIM Road Id / Slim Black Road Id / Sport Id / Gelang Kecemasan Toko883',
#   210000,
#   4.9,
#   'Jakarta Utara',
#   'toko883',
#   'lari'],
#  ['sepatu wanita cewe adidas replika kets sneaker murah',
#   67500,
#   4.7,
#   'Cimahi',
#   'Toko Nayla Naya',
#   'lari'],
#  ['celana olahraga lari tactico rechargo abu abu',
#   115000,
#   4.9,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Sepatu Adidas Pria',
#   112900,
#   4.6,
#   'Kab. Tangerang',
#   'bibu collection',
#   'lari'],
#  ['Celana Olahraga Pendek Dry Fit AD01',
#   55000,
#   4.8,
#   'Bandung',
#   'simplezone',
#   'lari'],
#  ['Sepatu running eagle Force original',
#   265000,
#   4.6,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'lari'],
#  ['celana lari tactico biru tua',
#   100000,
#   4.7,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Sepatu Lari Professional Trainer',
#   169900,
#   4.8,
#   'Tasikmalaya',
#   'PRIMA SPORTS',
#   'lari'],
#  ['Celana Training 01 Ukuran Jumbo',
#   22500,
#   4.3,
#   'Solo',
#   'Grosiran Pasar Klewer',
#   'lari'],
#  ['Athletica Official Shop - AT 693 All Black Sepatu Running Sepatu Pria',
#   375000,
#   '5',
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Celana Jogger Pants Nike Fc 3/4 Abu / joger pants',
#   42000,
#   4.8,
#   'Bandung',
#   'WANTOSHOP',
#   'lari'],
#  ['Celana Baselayer Panjang Longpants Manset Training Gym Legging Running Hiking',
#   23000,
#   4.6,
#   'Bandung',
#   'Taraje Store',
#   'lari'],
#  ['Kalibre Spibelt Race Pouch Waist Bag Tas Pinggang Lari Running Belt Sepeda Tipis Ringan Hitam 920466-000',
#   105000,
#   4.8,
#   'Bandung',
#   'KMD Shop',
#   'lari'],
#  ['Kinesiology Tape Plester Elastis untuk Otot saat berolahraga',
#   29000,
#   4.8,
#   'Jakarta Barat',
#   'BarangUnik.co',
#   'lari'],
#  ['Sepatu pria adidas alphabounce 2.0',
#   195000,
#   4.4,
#   'Bandung',
#   'dwcshop',
#   'lari'],
#  ['Athletica Official Shop - AT 693 Grey Black Sepatu Running Sepatu Pria',
#   375000,
#   4.9,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Sketcher Go Walk Slip on sepatu sneakers pria grade ori',
#   175000,
#   4.8,
#   'Jakarta Barat',
#   'claressa cloth',
#   'lari'],
#  ['Sepatu Lari Professional Racer',
#   154900,
#   4.8,
#   'Tasikmalaya',
#   'PRIMA SPORTS',
#   'lari'],
#  ['PIN Shoes Cleaner 250ml - Sabun Sepatu',
#   60000,
#   4.9,
#   'Surabaya',
#   'Pin id',
#   'lari'],
#  ['Handuk Alas Matras Yoga Mat Quick Dry Towel Microfiber Cepat Kering 01 - Biru',
#   75000,
#   4.9,
#   'Depok',
#   'LBS OFFICIAL STORE',
#   'lari'],
#  ['Tas Pinggang Lari Anti Air',
#   59000,
#   4.5,
#   'Jakarta Selatan',
#   'gadgetop',
#   'lari'],
#  ['Sepatu Running Eagle Fighter',
#   240200,
#   4.9,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['BOLA BASEBALL SOFTBALL',
#   68000,
#   '5',
#   'Jakarta Barat',
#   'Globalsport',
#   'lari'],
#  ['sepatu wanita sport sneakers olah raga lari senam jogging murah bagus',
#   68500,
#   4.4,
#   'Cimahi',
#   'Toko Nayla Naya',
#   'lari'],
#  ['Zubits Magnet Tali Sepatu Magnetic Shoelaces',
#   39500,
#   4.1,
#   'Jakarta Selatan',
#   'gadgetop',
#   'lari'],
#  ['Sepatu Jumbo Big Size Adidas Neo Questar Sport Running Olahraga Pria',
#   95000,
#   4.8,
#   'Gresik',
#   'LAPAK SEPATU SURABAYA',
#   'lari'],
#  ['celana pendek olahraga voli printing kolor volly bahan tebal',
#   45000,
#   4.6,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['LOCK LACES  LACE TALI SEPATU ELASTIS SERUT FLEKSIBEL KARET',
#   60000,
#   4.9,
#   'Tangerang',
#   'cantigi',
#   'lari'],
#  ['Tas Pinggang Lari Go Belt Multifungsi Olahraga Serbaguna Tas Perut',
#   35000,
#   4.7,
#   'Jakarta Barat',
#   'FASTOP',
#   'lari'],
#  ['celana olahraga lari altitude darkblue',
#   100000,
#   4.9,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Sepatu Lari Professional Runner',
#   169900,
#   4.9,
#   'Tasikmalaya',
#   'PRIMA SPORTS',
#   'lari'],
#  ['Tas Pinggang Lari Go belt SU0006 Tas Pinggang Lari Go belt SU0006',
#   15000,
#   4.2,
#   'Jakarta Pusat',
#   'gudang unik',
#   'lari'],
#  ['CHARGER GARMIN FENIX 5 5S 5X FORERUNNER 935',
#   49000,
#   4.9,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Sepatu Sekolah Sport Olah Raga Running Bola Futsal Casual Catenzo 1583',
#   205100,
#   4.8,
#   'Bandung',
#   'DISTRO GROSIR MURAH BANDUNG',
#   'lari'],
#  ['Celana Olahraga Pendek Lari Warna PUTIH RB01',
#   60000,
#   4.7,
#   'Bandung',
#   'simplezone',
#   'lari'],
#  ['Tas Pinggang 1525', 75000, 4.8, 'Bandung', 'eibag indonesia', 'lari'],
#  ['Tiento Celana Legging Pants 2in1 Sporty Black',
#   256150,
#   '5',
#   'Bandung',
#   'Tiento',
#   'lari'],
#  ['Sepatu Olahraga Eagle Thunderbolt Running Lari ORIGINAL',
#   232000,
#   4.8,
#   'Jakarta Barat',
#   'Reiko Store',
#   'lari'],
#  ['Geoff Max Athletica - AT 693 Grey White Shoes',
#   225000,
#   4.7,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Sepatu Eagle Ronin Merah Hitam - Premium Performance Running Shoes',
#   270400,
#   4.8,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Sepatu Lari Professional Leopard',
#   149900,
#   4.8,
#   'Tasikmalaya',
#   'PRIMA SPORTS',
#   'lari'],
#  ['Kolor single print celana voli badminton futsal printing',
#   27500,
#   4.6,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Spibelt Tas Pinggang Tas Lari Waist Running Bag Tas Olahraga',
#   22000,
#   4.6,
#   'Kab. Cirebon',
#   'Home Mart',
#   'lari'],
#  ['BOSU BALL BALANCE STEP BOSU BALL DENGAN POMPA',
#   545000,
#   '5',
#   'Jakarta Barat',
#   'Globalsport',
#   'lari'],
#  ['Universal Sport Armband Case Tempat Handphone (Hp) Untuk Olahraga Lari Ukuran L (Max 5.3 Inch)',
#   39000,
#   4.5,
#   'Jakarta Selatan',
#   'gadgetop',
#   'lari'],
#  ['Cone Kerucut Kone Kun Latihan Lari',
#   10000,
#   4.7,
#   'Jakarta Timur',
#   'ARSA SPORT',
#   'lari'],
#  ['Nineten 910 Ryu 1.5 Sepatu Training - Abu',
#   239900,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['BASELAYER MANSET NIKE PRO PANJANG GRADE ORI BOLA LARI SEPEDA',
#   79000,
#   4.8,
#   'Jakarta Barat',
#   'Super Jersey',
#   'lari'],
#  ['Nineten 910 Yuza Evo Sepatu Trail running - Hitam-Burgundy-Abu-Ash',
#   395000,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Geoff Max Athletica - AT 693 Navy White Shoes',
#   225000,
#   4.8,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Kneepad 1 set Knee and Elbow Deker Tactical Combat 1 set Lutut Sikut',
#   75000,
#   '5',
#   'Jakarta Pusat',
#   'OutdoorSPLY',
#   'lari'],
#  ['celana fullprinting voli jpe kolor voly jakarta pertamina',
#   45000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['AONIJIE - RACE BELT',
#   67000,
#   4.7,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Tongkat Estafet / Relay stick',
#   15000,
#   '5',
#   'Jakarta Timur',
#   'MUTIARA SPORT',
#   'lari'],
#  ['Sepatu Running Eagle Lucius',
#   259000,
#   4.8,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'lari'],
#  ['Diadora sepatu lari original asli termurah 2 warna',
#   349000,
#   4.7,
#   'Solo',
#   'TRANS SPORTS',
#   'lari'],
#  ['Waterproof Waist Bag Running Belt Tas Pinggang Jogging Lari Olahraga',
#   24000,
#   4.6,
#   'Kab. Cirebon',
#   'Home Mart',
#   'lari'],
#  ['Nineten 910 Geist Ekiden Sepatu Lari - Merah Abu',
#   385000,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['AVTECH Celana Pendek Skam',
#   190000,
#   4.8,
#   'Jakarta Timur',
#   'Avtech Official Store',
#   'lari'],
#  ['MOUNTING MARCOOL', 85000, 4.7, 'Bandung', 'MEGAH SPORTS', 'lari'],
#  ['Sepatu Sekolah Sport Olah Raga Bola Futsal Casual Catenzo 103 DY 032',
#   215400,
#   4.6,
#   'Bandung',
#   'DISTRO GROSIR MURAH BANDUNG',
#   'lari'],
#  ['Nineten 910 Geist Ekiden Elite Sepatu Running - Merah-Putih Gading',
#   400000,
#   4.7,
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Tas Hydropack Running-Tas Lari Reuma R2042',
#   225000,
#   4.9,
#   'Kab. Bandung',
#   'Reuma',
#   'lari'],
#  ['Tempered Glass For Suunto Spartan Trainer Wrist HR Thin Clear Scratch Resistant Screen Protector Guard',
#   67000,
#   4.7,
#   'Bekasi',
#   'KYFF Shop',
#   'lari'],
#  ['Buy 1 Get 1 Spibelt Black Tas Pinggang Tas Lari Waist Running Bag Tas Olahraga',
#   58320,
#   4.4,
#   'Kab. Tangerang',
#   'Indo Dealz',
#   'lari'],
#  ['Nineten 910 Geist Ekiden Sepatu Running - Biru Dongker-Abu Muda-Jingga',
#   385000,
#   4.9,
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Tali Sepatu Magnet - 2pcs', 35730, 4.7, 'Cilegon', 'Havi Store', 'lari'],
#  ['Celana Olahraga Pendek Warna Putih AD01 Celana Santai',
#   60000,
#   4.8,
#   'Bandung',
#   'simplezone',
#   'lari'],
#  ['Geoff Max Athletica - AT 555 Lite Grey Sepatu Running Sepatu Pria Sneakers',
#   450000,
#   4.9,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['New Product - Reuma Hydrations bag - Tas Lari- Trailrun-Running vest - The Runner R2045',
#   225000,
#   4.8,
#   'Kab. Bandung',
#   'Reuma',
#   'lari'],
#  ['BRACKET BREKET HOLDER SENTER MODEL PUTAR 360',
#   8200,
#   4.6,
#   'Bekasi',
#   'ANNIA SHOP',
#   'lari'],
#  ['KANTONG BiB SAJA BIBfolio extension - gantungan BIB',
#   2500,
#   '5',
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Tempered Glass For Garmin Forerunner 235 Ultra Thin Clear Scratch Resistant Screen Protector Guard',
#   72000,
#   4.9,
#   'Bekasi',
#   'KYFF Shop',
#   'lari'],
#  ['LP Support Athletic Supporter SUpporter Olahraga Ukuran S M L XL - S',
#   103151,
#   '5',
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'lari'],
#  ['Dawei Blue Devil SG 250ml Lem Bensin Speed Glue',
#   65000,
#   4.8,
#   'Bandung',
#   'IndoPingpong',
#   'lari'],
#  ['COD Celana Pendek Quickdry Elastis - Celana Gunung Olahraga Outdoor - Celana Trekking Camping',
#   65000,
#   4.6,
#   'Bekasi',
#   'bogabooindonesia',
#   'lari'],
#  ['Jual Spibelt Tas Pinggang Tas Lari Waist Running Bag Tas Olahraga',
#   29952,
#   4.7,
#   'Kab. Tangerang',
#   'Zee Acc',
#   'lari'],
#  ['Spibelt Black Tas Pinggang Tas Lari Waist Running Bag Tas Olahraga',
#   129000,
#   4.5,
#   'Jakarta Selatan',
#   'AKSESORIS HITS',
#   'lari'],
#  ['Celana Olahraga MIZUNO Polos', 60000, 4.8, 'Bandung', 'simplezone', 'lari'],
#  ['Nineten 910 Yuza Sepatu Lari Trail Running - Navy-Hitam-Abu',
#   329900,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Tiento Celana Olahraga Running Leging Legging Pants 2in1 Sebetis Sporty Black Men',
#   239150,
#   4.8,
#   'Bandung',
#   'Tiento',
#   'lari'],
#  ['Sepatu Sport Running Fabric Harga Murah',
#   200000,
#   '5',
#   'Jakarta Pusat',
#   'MARLABA',
#   'lari'],
#  ['Tas Pinggang Lari Go Belt Multifungsi Olahraga Serbaguna Impor',
#   36000,
#   4.7,
#   'Jakarta Barat',
#   'FASTOP',
#   'lari'],
#  ['Baselayer Anak Nike Manset anak',
#   50000,
#   4.9,
#   'Jakarta Selatan',
#   'MEHER STORE',
#   'lari'],
#  ['Nineten 910 Haze 1.5 Sepatu Lari - Hitam - Merah',
#   380000,
#   4.8,
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['LP Adjustable Ankle Support Deker Pelindung Mata Kaki Olahraga - Hitam S',
#   156600,
#   4.9,
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'lari'],
#  ['Sepatu Sport Running Jumbo Big Size 44 45 46 47 48 Nike Airmax Tpr',
#   95000,
#   '5',
#   'Gresik',
#   'LAPAK SEPATU SURABAYA',
#   'lari'],
#  ['Sepatu Lari Running Ortuseight Phyton Black White 11030076 Original BNIB',
#   279650,
#   '5',
#   'Jakarta Timur',
#   'KING OF DRIBBLE',
#   'lari'],
#  ['celana volly full printing fulprin kolor voli badminton futsal',
#   45000,
#   4.7,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['celana olahraga lari tactico proven abu',
#   100000,
#   4.7,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Sepatu Lari Spotec Liquid',
#   229900,
#   4.9,
#   'Tasikmalaya',
#   'PRIMA SPORTS',
#   'lari'],
#  ['kaos olahraga CLARITY BLACK RED',
#   150000,
#   4.8,
#   'Kab. Bandung',
#   'migraphcorner shop',
#   'lari'],
#  ['Sepatu Running Lari Nike Original Downshifter 11 Black CW3411-002 BNIB',
#   799000,
#   4.9,
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['Sepatu Nike Vapor max Original - Nike Vapormax - Air vapor max',
#   299000,
#   4.7,
#   'Kab. Tangerang',
#   'ZONA SEPATU 39',
#   'lari'],
#  ['Nineten 910 Geist Ekiden Sepatu Running - Hitam Biru',
#   385000,
#   4.9,
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['kaos olahraga SOLARIZT BLACK YELLOW',
#   150000,
#   4.8,
#   'Kab. Bandung',
#   'migraphcorner shop',
#   'lari'],
#  ['Gratis Botol minum! Neoprene Hydration Sports Running bottle Belt / tas pinggang olahraga',
#   165000,
#   '5',
#   'Jakarta Barat',
#   'DJB DatangJualBeli',
#   'lari'],
#  ['Celana Pendek Lari Tactico PROVEN black',
#   99000,
#   4.8,
#   'Kab. Bandung',
#   'thunderstar_shop',
#   'lari'],
#  ['CELANA PANJANG TRAINING RUNNING PROMO TERLARIS',
#   75000,
#   4.2,
#   'Jakarta Barat',
#   'EMOLINE 8',
#   'lari'],
#  ['Celana Pendek Lari Tactico MOMENT black',
#   99000,
#   4.8,
#   'Kab. Bandung',
#   'thunderstar_shop',
#   'lari'],
#  ['kolor voli celana badminton futsal singel printing',
#   27000,
#   4.9,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['sepatu lari diadora ori asli original termurah',
#   349000,
#   4.9,
#   'Solo',
#   'TRANS SPORTS',
#   'lari'],
#  ['Sepatu Eagle Eternal Merah Hitam - Running Shoes',
#   200100,
#   4.7,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Eco Squeeze Bottle With BPA Free / Foldable Bottle',
#   70000,
#   4.5,
#   'Tangerang',
#   'Brightfull',
#   'lari'],
#  ['Geoff Max Athletica - AT 555 Black Grey Sepatu Running Sepatu Pria Sneakers',
#   450000,
#   '5',
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['SUPER SALE !!! Paket Baselayer Paket Baju dan celana Renang longsleeve lengan panjang + Celana Pendek manset nike Underamour 01',
#   55800,
#   4.3,
#   'Bekasi',
#   'Ivan Gym stells',
#   'lari'],
#  ['POPOR CTR OG729', 128000, 4.8, 'Bandung', 'MEGAH SPORTS', 'lari'],
#  ['Tiento Celana Olahraga Running Leging Legging Pants 2in1 Short Sporty Black Men',
#   196650,
#   4.9,
#   'Bandung',
#   'Tiento',
#   'lari'],
#  ['Salzmann Reflective Band / Gelang Reflektor',
#   58000,
#   '5',
#   'Jakarta Utara',
#   'Hike n Run Official Store',
#   'lari'],
#  ['HOT SHAPERS PANTS/CELANA SENAM/PELANGSING/JOGGING/FITNES',
#   39000,
#   3.8,
#   'Surabaya',
#   'tokomurah',
#   'lari'],
#  ['Jersey All Mountain Trail Hardside CLARITY blackred',
#   150000,
#   4.9,
#   'Kab. Bandung',
#   'thunderstar_shop',
#   'lari'],
#  ['Tempered Glass For Garmin Forerunner 735XT Ultra Thin Clear Scratch Resistant Screen Protector Guard',
#   67000,
#   4.9,
#   'Bekasi',
#   'KYFF Shop',
#   'lari'],
#  ['MANSET KAKI LEG WARMER  KNEE WARMER  LEG SLEEVE  SEPEDA RUNNING LARI FITNES MANGSET KAKI lentur dan nyaman',
#   79900,
#   4.8,
#   'Banjar',
#   'Mega Bike Jabar',
#   'lari'],
#  ['Celana Sepeda Balap Anak Tanggung - Celana Sepeda Ketat Padding Busa',
#   45000,
#   4.8,
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'lari'],
#  ['GARMIN Instinct - Terbaru Bergaransi',
#   4595000,
#   4.9,
#   'Tangerang',
#   'TRACKINDO UTAMA',
#   'lari'],
#  ['Sepatu Lari Spotec Blaze',
#   229900,
#   4.8,
#   'Tasikmalaya',
#   'PRIMA SPORTS',
#   'lari'],
#  ['Tempered Glass For Suunto Spartan Ultra Thin Clear Scratch Resistant Screen Protector Guard',
#   72000,
#   4.8,
#   'Bekasi',
#   'KYFF Shop',
#   'lari'],
#  ['celana olahraga lari quickdry',
#   100000,
#   4.8,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Import Sepatu Nike Neo Zoom Max Terlaris',
#   165000,
#   4.1,
#   'Bandung',
#   'Kujang Grosir BDG',
#   'lari'],
#  ['Monokini No. 07 Bikini Kualitas Import',
#   75000,
#   '4',
#   'Jakarta Barat',
#   'duniaCGC2',
#   'lari'],
#  ['celana voli polos logo proliga pbvsi samator printing kolor voly',
#   25000,
#   4.8,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['CELANA JOGGER REEBOK PANJANG - SWEATPANTS - TRAINING REEBOK JOGGER PANT',
#   37900,
#   4.4,
#   'Bekasi',
#   'JSHOP JERSEY',
#   'lari'],
#  ['Sepatu Eagle Charlote - Running Shoes',
#   223920,
#   4.8,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Sepatu Olahraga wanita adidas zoom',
#   278000,
#   '5',
#   'Bandung Barat',
#   'ADRS FOOTWEAR PROJECT',
#   'lari'],
#  ['Kabel Data Charger Fast Charging Garmin Fenix 5 5S 5x Vivoactive 3',
#   49999,
#   '5',
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['sepatu adidas neo ori import',
#   195000,
#   4.6,
#   'Kab. Tangerang',
#   'Riskia store',
#   'lari'],
#  ['Sepatu Eagle Speed Line - Running Shoes',
#   198200,
#   4.7,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Nineten 910 Geist Ekiden Elite Sepatu Running - Hitam-Merah-Putih',
#   549900,
#   4.9,
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Celana Sepeda Balap 3 4 - Celana Sepeda Ketat Padding Busa',
#   70000,
#   'no rating',
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'lari'],
#  ['Celana Pendek Lari RECHARGO black',
#   115000,
#   4.9,
#   'Kab. Bandung',
#   'thunderstar_shop',
#   'lari'],
#  ['Race Number BIB Button - Kancing BIB Lari Marathon',
#   35000,
#   4.9,
#   'Jakarta Utara',
#   'ABC Mart',
#   'lari'],
#  ['celana sepeda panjang padding Busa mtb ketat pria wanita cowok cewek',
#   85000,
#   4.7,
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'lari'],
#  ['Sepatu Eagle Magnum Running Shoes',
#   240200,
#   '5',
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Kalenji ONRHYTHM 110 Jam Tangan Heart Rate Monitor Watch Original - Hitam',
#   450000,
#   4.8,
#   'Tangerang',
#   'Byron Official',
#   'lari'],
#  ['adidas eqt sepatu olahraga wanita import',
#   239000,
#   4.9,
#   'Bandung Barat',
#   'ADRS FOOTWEAR PROJECT',
#   'lari'],
#  ['Sepatu Running Lari Specs Cloudwave Maroon Orange 200645 Original BNIB',
#   379800,
#   '5',
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['MONOPOD CAMO AS291', 200000, 4.9, 'Bandung', 'MEGAH SPORTS', 'lari'],
#  ['CELANA JOGGER MIZUNO 3-4 TRAINING - SWEATPANTS MIZUNO HITAM',
#   32900,
#   4.9,
#   'Bekasi',
#   'JSHOP JERSEY',
#   'lari'],
#  ['Sepatu Running Lari Adidas Fluidstreet Core Black FW1703 Original BNIB',
#   1092500,
#   4.9,
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['PTP109 Plastik Perekat uk 22x30 cm Ukuran Baju Anak isi 100 pcs',
#   23000,
#   '5',
#   'Jakarta Timur',
#   'Tokokainflanel',
#   'lari'],
#  ['Celana Olahraga Pendek - Celana Lari - Celana Running li-ning n under',
#   49900,
#   4.7,
#   'Jakarta Selatan',
#   'aisy fashion',
#   'lari'],
#  ['Tas Lari AONIJIE Running Vest Hydration Pack C933',
#   595000,
#   '5',
#   'Jakarta Utara',
#   'Hike n Run Official Store',
#   'lari'],
#  ['StopWatch Anytime XL-008 / Stop Watch / Timer',
#   28500,
#   '5',
#   'Jakarta Barat',
#   'zalfa_shops',
#   'lari'],
#  ['Sepatu Olahraga Pria Sneakers Sport Running Casual Nike Flyknit Import',
#   250000,
#   4.8,
#   'Kab. Bandung',
#   'Bdg Footwear Store',
#   'lari'],
#  ['celana lari tactico RECHARGO BLACK',
#   115000,
#   4.8,
#   'Kab. Bandung',
#   'migraphcorner shop',
#   'lari'],
#  ['Sepatu Eagle Ronin Hijau Putih - Premium Performance Running Shoes',
#   270400,
#   4.9,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Celana Olahraga Bahan Dry-Fit RB01 Celana Olahraga Lari',
#   55000,
#   4.8,
#   'Bandung',
#   'simplezone',
#   'lari'],
#  ['Nineten 910 Sera Sepatu Lari - Abu Muda-Ungu-Merah Muda',
#   279900,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Celana Olahraga Pendek Celana Lariii Pria Dewasaaaaa',
#   30250,
#   4.6,
#   'Bandung',
#   'Toko Sepeda Abah',
#   'lari'],
#  ['Sepatu Eagle Dragon Biru Putih - Running Shoes',
#   250200,
#   4.9,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Aonijie E4055 Sport Reflective Shoelace BLACK',
#   25000,
#   4.9,
#   'Jakarta Utara',
#   'Aonijie Indonesia',
#   'lari'],
#  ['Sepatu Eagle Avro Running Shoes',
#   182200,
#   '5',
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['ANT+ heart rate monitor strap - GOLIFE for Garmin Suunto BRYTON',
#   398900,
#   4.9,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Geoff Max Athletica - AT 555 Black White Sepatu Running Sepatu Pria Sneakers',
#   450000,
#   4.9,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Tali skipping kettler aluminium swift jump rope',
#   170000,
#   4.9,
#   'Jakarta Barat',
#   'johan',
#   'lari'],
#  ['Rockbros KZ1001 Active Carbon Filter - Saringan Masker Sepeda Lari',
#   20000,
#   '5',
#   'Jakarta Utara',
#   'Rockbrothers Indonesia',
#   'lari'],
#  ['Klip Lampu Sepatu LED Safety Light',
#   19000,
#   4.6,
#   'Jakarta Barat',
#   'ROMANET',
#   'lari'],
#  ['Bola Putih Billiard GACO billiard 2 1 4 titik 6',
#   25000,
#   4.3,
#   'Jakarta Barat',
#   'Globalsport',
#   'lari'],
#  ['Kalenji Kanergy Deker Betis Lari Kompresi Mengurangi Kelelahan Otot',
#   199000,
#   4.9,
#   'Tangerang',
#   'Byron Official',
#   'lari'],
#  ['Sepatu Eagle Falcon 2 - Running Shoes',
#   240200,
#   4.9,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Kalenji Sun Protect Baju Lari Anti UV Men Running Tshirt - Putih',
#   195000,
#   4.8,
#   'Tangerang',
#   'Byron Official',
#   'lari'],
#  ['Spibelt Tas Pinggang Tas Lari Waist Running Bag Tas Olahraga',
#   29640,
#   4.2,
#   'Kab. Tangerang',
#   'Indo Dealz',
#   'lari'],
#  ['AVTECH - Celana Pendek Alcro',
#   125000,
#   4.9,
#   'Jakarta Timur',
#   'Avtech Official Store',
#   'lari'],
#  ['Celana Leging Wanita Panjang Pendek olahraga',
#   40000,
#   '5',
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'lari'],
#  ['Sepatu Eagle Ecolight 2 - Running Shoes',
#   271920,
#   4.8,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['MEDAL HANGER - GANTUNGAN MEDALI - FEAR NO DISTANCE',
#   198000,
#   4.9,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Kalenji Topi Visor Lari Topi Running Topi Olahraga Lari Original - Hitam',
#   145000,
#   4.7,
#   'Tangerang',
#   'Byron Official',
#   'lari'],
#  ['Celana Pendek Lari Tactico ESSENT black',
#   110000,
#   4.5,
#   'Kab. Bandung',
#   'thunderstar_shop',
#   'lari'],
#  ['Nineten 910 Geist Ekiden Elite Sepatu Running - Biru-Hijau Neon-Putih',
#   400000,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Athletica Official Shop - Warner 1 Black White Sepatu Running Sepatu Pria',
#   345000,
#   4.6,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Sepatu Running Lari Adidas Galaxy 5 Black FY6718 Original BNIB',
#   700000,
#   4.9,
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['Sepatu running wanita HS009 sepatu santai original hipzo sepatu senam',
#   199000,
#   4.8,
#   'Kab. Mojokerto',
#   'Hipzo Official Shop',
#   'lari'],
#  ['EVS MEN Compression Tight Pants With MCS. Black',
#   350000,
#   4.9,
#   'Jakarta Utara',
#   'toko883',
#   'lari'],
#  ['Athletica Official Shop - Warner 1 Dark Grey Sepatu Running Sepatu Pria',
#   345000,
#   '5',
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Go Belt pocket Running Tas Pinggang Lari Multifungsi Murah',
#   33535,
#   3.9,
#   'Bandung',
#   'Onejual Online',
#   'lari'],
#  ['Sepatu Lari  Adidas Original Duramo Sl Triple Black Fw7393',
#   699000,
#   '5',
#   'Bandung',
#   'NCR Sport',
#   'lari'],
#  ['Sepatu Eagle Felice - Running Shoes',
#   210200,
#   '5',
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Nineten 910 Haze 1.5 Sepatu Lari -Hitam-Hijau Neon-Putih',
#   380000,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Sepatu Running Lari Adidas Asweerun 2.0 Legend Ink FW1682 Original',
#   700000,
#   4.9,
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['Aonijie E4086 Sweatband Elastic - Headband penahan keringat kepala - BLACK',
#   60000,
#   4.9,
#   'Jakarta Utara',
#   'Aonijie Indonesia',
#   'lari'],
#  ['Nineten 910 Haze 1.5 Sepatu Lari - Biru Dongker-Orange',
#   380000,
#   4.8,
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Liton Ankle Support 8624/Deker Pelindung mata kaki/perlindungan pergelangan',
#   18500,
#   4.9,
#   'Jakarta Barat',
#   'AVATAR Collections',
#   'lari'],
#  ['MyYoora Summer Sporty Running Shorts Celana Pendek Wanita JP369',
#   60000,
#   4.9,
#   'Bandung',
#   'MyYoora Official',
#   'lari'],
#  ['MANSET KAKI LEG WARMER KNEE WARMER LEG SLEEVE SEPEDA CYCLING JOGGING RUNNING LARI FITNES MANGSET KAKI paha lentur dan nyaman legsleeve unisex',
#   100000,
#   4.6,
#   'Banjar',
#   'Mega Bike Jabar',
#   'lari'],
#  ['Sepatu Running Lari Adidas Runfalcon 2.0 Core Black FY5943 Original BNIB',
#   640000,
#   4.8,
#   'Jakarta Timur',
#   'KING OF DRIBBLE',
#   'lari'],
#  ['Sport Shoes Pria LAL Sepatu Running Olahraga Hitam Putih',
#   102960,
#   'no rating',
#   'Jakarta Selatan',
#   'OLA',
#   'lari'],
#  ['Athletica Official Shop - Flash Ghost Black Red Sepatu Running Sepatu Pria Sneakers',
#   450000,
#   '5',
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['sepatu pria sepatu kets sepatu running adidas import',
#   255000,
#   4.8,
#   'Kab. Tangerang',
#   'Riskia store',
#   'lari'],
#  ['Strap Garmin Forerunner 220 230 235 620 630 735 XT Watch Band Replacement Tali Jam - HITAM',
#   99000,
#   4.9,
#   'Bekasi',
#   'KYFF Shop',
#   'lari'],
#  ['Celana Pendek Lari Tactico ZEKTOR black',
#   120000,
#   4.9,
#   'Kab. Bandung',
#   'thunderstar_shop',
#   'lari'],
#  ['Sepatu Eagle Ronin Hitam - Premium Performance Running Shoes',
#   270400,
#   4.5,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['CELANA PANJANG PINNACLE EUTLA SERIES CELANA GUNUNG QUICKDRY BAHAN CEPAT KERING',
#   195000,
#   4.9,
#   'Sidoarjo',
#   'Omah Alas Adventure',
#   'lari'],
#  ['Paket Hemat 3 Pcs - Jelana Pendek Jogger Sport Running Gym',
#   122000,
#   4.7,
#   'Jakarta Barat',
#   'Zahra Clothing',
#   'lari'],
#  ['Race BIB Button - Kancing BIB nomor dada Lomba Lari 1 set isi 4',
#   34000,
#   '5',
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['tas pinggang double pocket',
#   25000,
#   4.9,
#   'Bekasi',
#   'Premier EO Bike',
#   'lari'],
#  ['Adidas Neo City Racer Black strip grey',
#   160000,
#   4.1,
#   'Kab. Bandung',
#   'rVn Footwear',
#   'lari'],
#  ['Kalenji Trail Run Belt 2 x 500 ml Water Bladder - Black Bronze',
#   435000,
#   '5',
#   'Tangerang',
#   'Byron Official',
#   'lari'],
#  ['Sepatu casual running 910 nineten Kazuri black',
#   259900,
#   4.8,
#   'Jakarta Pusat',
#   'KEDAI SPORT',
#   'lari'],
#  ['Celana Olahraga Pendek Kantong RESLETING LI01',
#   70000,
#   4.9,
#   'Bandung',
#   'simplezone',
#   'lari'],
#  ['Nineten 910 Yuza Sepatu Lari Trail Running - Coklat-Hitam-Abu-Abu',
#   329900,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Athletica Official Shop - Flash Ghost Dark Shine On  Sepatu Running  Sepatu Pria  Sneakers',
#   450000,
#   '5',
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['INDORUNNERS RED - MEDAL HANGER - GANTUNGAN MEDALI',
#   199000,
#   4.8,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Sepatu Sekolah Sport Olah Raga Running Bola Futsal Casual Catenzo 1585',
#   213600,
#   4.5,
#   'Bandung',
#   'DISTRO GROSIR MURAH BANDUNG',
#   'lari'],
#  ['Sepatu Vans Olskool Klasik kids sepatu vans anak',
#   99000,
#   4.6,
#   'Jakarta Barat',
#   'claressa cloth',
#   'lari'],
#  ['Sepatu lari running sepatu gunung 910 Original YUZA cokelat abu abu new 2021',
#   299925,
#   '5',
#   'Jakarta Pusat',
#   'Kicosport Official',
#   'lari'],
#  ['bending pasir / pemberat kaki 4 kg @2kg',
#   50000,
#   4.5,
#   'Semarang',
#   'DERA SPORT',
#   'lari'],
#  ['PROMO TERLARIS SETELAN OLAHRAGA PRIA WANITA BAJU JOGGING LARI PEMBAKAR LEMAK SAUNA HOT SHAPE JAKET CELANA KUALITAS TERBAIK',
#   85277,
#   '5',
#   'Medan',
#   'Onlineshop Medan',
#   'lari'],
#  ['celana panjang lari tactico de primo',
#   165000,
#   4.9,
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Sepatu Olahraga Eagle Hyperfit Running Lari ORIGINAL',
#   243000,
#   4.8,
#   'Jakarta Barat',
#   'Reiko Store',
#   'lari'],
#  ['Celana Training Panjang Lotto  Pria dan Wanita',
#   45000,
#   4.7,
#   'Cimahi',
#   'Fashion Ts Trendy',
#   'lari'],
#  ['ArmBand Arm Band Size L', 15500, 4.9, 'Kab. Bekasi', 'Dhe Acc', 'lari'],
#  ['Sepatu Running Lari Nike Revolution 5 Midnight Navy BQ3204-400 Original BNIB',
#   599250,
#   4.8,
#   'Jakarta Timur',
#   'KING OF DRIBBLE',
#   'lari'],
#  ['Kalenji Run One Sepatu Olahraga Lari Wanita Original - Abu-abu',
#   230000,
#   4.7,
#   'Tangerang',
#   'Byron Official',
#   'lari'],
#  ['Sepatu Running Lari Nike Downshifter 10 Black CI9981-002 Original BNIB',
#   599250,
#   '5',
#   'Jakarta Timur',
#   'KING OF DRIBBLE',
#   'lari'],
#  ['Sepatu Running Lari Nineten Haze 1.5 Hitam Abu R65018810121 Original BNIB',
#   359920,
#   '5',
#   'Jakarta Timur',
#   'KING OF DRIBBLE',
#   'lari'],
#  ['Cone Cones 23 cm Kerucut Full Rapat Tidak Lubang',
#   5700,
#   '2',
#   'Jakarta Utara',
#   'BISTOREID',
#   'lari'],
#  ['Joola Lakban Edge Tape SideTape EdgeTape Side',
#   9000,
#   '5',
#   'Bandung',
#   'IndoPingpong',
#   'lari'],
#  ['Xiom Blue Lakban Edge Tape SideTape EdgeTape Side Biru',
#   10000,
#   4.9,
#   'Bandung',
#   'IndoPingpong',
#   'lari'],
#  ['Tas Pinggang Olah Raga Lari Jogging Jalan Marathon dengan Botol',
#   135000,
#   4.9,
#   'Bandung',
#   'Secret Adventure',
#   'lari'],
#  ['EXPOWER - EXP Compression Tight with MCS - Size S - Celana Lari',
#   349990,
#   4.9,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Athletica Official Shop - Flash Ghost Navy Red Sepatu Running  Sepatu Pria  Sneaker',
#   450000,
#   4.9,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Speed Chute Speed Training Resistance Parachute',
#   46900,
#   4.9,
#   'Jakarta Barat',
#   'Galuh Saputra',
#   'lari'],
#  ['PRM Prima Super', 60000, '5', 'Surabaya', 'HS Store. ID', 'lari'],
#  ['Sepatu Running Lari Nike Revolution 5 BQ3204-404 Original BNIB',
#   639200,
#   '5',
#   'Jakarta Timur',
#   'KING OF DRIBBLE',
#   'lari'],
#  ['Sepatu Lari Wanita  Reebok Original Wmns Runner 4.0 Cold Grey Fv1610',
#   699000,
#   '5',
#   'Bandung',
#   'NCR Sport',
#   'lari'],
#  ['Sepatu Running Lari Nike Downshifter 10 Black CI9981-002 Original BNIB',
#   799000,
#   '5',
#   'Jakarta Timur',
#   'King Drible',
#   'lari'],
#  ['celana lari tactico ESSENT dark blue',
#   110000,
#   '5',
#   'Kab. Bandung',
#   'arm sport',
#   'lari'],
#  ['Seamoon Booster 100ml Solubility Bond Booster',
#   250000,
#   4.8,
#   'Bandung',
#   'IndoPingpong',
#   'lari'],
#  ['celana olahraga lari jogging ZEKTOR BLACK',
#   120000,
#   4.9,
#   'Kab. Bandung',
#   'migraphcorner shop',
#   'lari'],
#  ['celana lari jogging tactico DARK BLUE',
#   115000,
#   4.8,
#   'Kab. Bandung',
#   'migraphcorner shop',
#   'lari'],
#  ['Kalenji Run One Sepatu Olahraga Lari Pria Boost EVA Technology Original - Abu',
#   230000,
#   4.4,
#   'Tangerang',
#   'Byron Official',
#   'lari'],
#  ['Tempered Glass For Garmin Forerunner 35 Ultra Thin Clear Scratch Resistant Screen Protector Guard',
#   67000,
#   4.9,
#   'Bekasi',
#   'KYFF Shop',
#   'lari'],
#  ['Athletica Official Shop - ATH 4 Navy Red White Sepatu Running Sepatu Pria',
#   375000,
#   '5',
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['Sepatu Running Lari Nineten Ryu 1.5 Dark Grey A1010320623 Original BNIB',
#   209930,
#   '5',
#   'Jakarta Timur',
#   'KING OF DRIBBLE',
#   'lari'],
#  ['bending pasir / pemberat kaki 2 kg @1 kg',
#   40000,
#   4.8,
#   'Semarang',
#   'DERA SPORT',
#   'lari'],
#  ['Sepatu Eagle Evo Racer - Running Shoes',
#   245200,
#   4.8,
#   'Jakarta Timur',
#   'Eagle Indonesia',
#   'lari'],
#  ['Sepatu Running Adidas Ultra Boost Grey/Abu Men/Cowok/Pria Murah Casual Import Vietnam',
#   189000,
#   3.9,
#   'Tangerang Selatan',
#   'ELARIO SPORT OUTDOOR',
#   'lari'],
#  ['Athletica Official Shop - Fortis Black White Sepatu Running Sepatu Olahraga',
#   375000,
#   4.7,
#   'Bandung',
#   'Geoff Max Footwear',
#   'lari'],
#  ['HURDLE SPEEDS ISI 5PCS ALAT MELATIH REFLEK LX 037-6 15CM',
#   140000,
#   'no rating',
#   'Jakarta Barat',
#   'Globalsport',
#   'lari'],
#  ['Bundling 910 Fuka Socks - Drak Grey',
#   30000,
#   '5',
#   'Kab. Tangerang',
#   '910 ninetenshoes',
#   'lari'],
#  ['Celana manset legging olahraga',
#   85000,
#   4.8,
#   'Karanganyar',
#   'BL strike_fishing',
#   'lari'],
#  ['MEDAL HANGER - GANTUNGAN MEDALI',
#   200000,
#   4.9,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Strap Garmin Fenix 3 Watch Band Replacement Tali Jam - Dark Red',
#   97000,
#   4.9,
#   'Bekasi',
#   'KYFF Shop',
#   'lari'],
#  ['AONIJIE FLIPBELT - SIZE M - HITAM',
#   140000,
#   4.8,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['Celana Jogger Nike Fc 3/4 Termurah',
#   42000,
#   4.8,
#   'Bandung',
#   'luckysports',
#   'lari'],
#  ['CELANA POLOS PENDEK BABYTERRY RUNNING GYM SPORT',
#   22999,
#   4.6,
#   'Tangerang Selatan',
#   'AF_SPORT JERSEY KONVEKSI',
#   'lari'],
#  ['Running Sports Bag Mobile phone Belt - Tas Pinggang HP Serba Guna',
#   31000,
#   4.9,
#   'Tangerang Selatan',
#   'Futureshop Official',
#   'lari'],
#  ['Karpet Pilates Yoga - Multi-Color Karpet Olahraga',
#   62000,
#   4.9,
#   'Jakarta Barat',
#   'Bosgentongs Shop',
#   'lari'],
#  ['Celana Olahraga Pendek Celana Lariii',
#   55000,
#   4.8,
#   'Bandung',
#   'Toko Sepeda Abah',
#   'lari'],
#  ['Celana Training Bordir Murah',
#   19500,
#   4.4,
#   'Solo',
#   'Grosiran Pasar Klewer',
#   'lari'],
#  ['Puma Sepatu Running PUMA Flyer Beta SoftFoam Plus  Running Shoes 19427402 - Puma Factory Outlet',
#   559300,
#   '5',
#   'Jakarta Barat',
#   'Puma APF Factory outlet',
#   'lari'],
#  ['kaos lari gym', 100000, '5', 'Kab. Bandung', 'arm sport', 'lari'],
#  ['Eagle HOKAIDO Sepatu Olahraga Running Lari Sneakers Kasual Pria Men',
#   265000,
#   4.9,
#   'Jakarta Barat',
#   'Reiko Store',
#   'lari'],
#  ['stopwatch penghitung pengukur waktu frasser 009 a',
#   25000,
#   4.9,
#   'Surabaya',
#   'Pusat Grosir Olahraga',
#   'lari'],
#  ['Garmin Forerunner 35 FR35 - strap band tali jam - BLACK',
#   69000,
#   4.8,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['kolor voli celana voly proliga jpe jakarta pertamina energi',
#   45000,
#   4.9,
#   'Jakarta Barat',
#   'IZDIHAAR SPORT',
#   'lari'],
#  ['Celana Joger Training / Sweatpatns Adidas Nike Grade Ori',
#   45000,
#   4.8,
#   'Kab. Bandung',
#   'FRANKIES SPORT',
#   'lari'],
#  ['Sepatu Converse Anak Sepatu allstar kids motif upstrak',
#   165000,
#   4.6,
#   'Jakarta Barat',
#   'claressa cloth',
#   'lari'],
#  ['Stopwatch QQ HS43', 170000, '5', 'Jakarta Barat', 'One piece shop', 'lari'],
#  ['Nike Running Airmax', 105000, 3.8, 'Mojokerto', 'Neas16_Shop', 'lari'],
#  ['Sepatu running 910 Original Geist Ekiden biru dongker new arrival 2021',
#   359925,
#   4.8,
#   'Jakarta Pusat',
#   'Kicosport Official',
#   'lari'],
#  ['Sepatu casual 910 nineten osaka black',
#   219900,
#   '5',
#   'Jakarta Pusat',
#   'KEDAI SPORT',
#   'lari'],
#  ['Sepatu Lari Spotec Gerald',
#   219900,
#   4.8,
#   'Tasikmalaya',
#   'PRIMA SPORTS',
#   'lari'],
#  ['Celana Olahraga Pendek Bahan Lembut ADT01 Celana Olahraga Bulutangkis',
#   64000,
#   '5',
#   'Bandung',
#   'simplezone',
#   'lari'],
#  ['LED Armband', 45000, '5', 'Jakarta Timur', 'Shafa Toys', 'lari'],
#  ['KABEL CHARGER GARMIN FENIX 3 D2',
#   109999,
#   4.8,
#   'Tangerang Selatan',
#   'Hangermedal',
#   'lari'],
#  ['PROMO !! Viper Speed Chute Speed Training Resistance Parachute Parasut untuk Latihan Berlatih Lari Profesional Kecang Resistensi Besar',
#   46000,
#   4.4,
#   'Kab. Bandung',
#   'Rimas Technology',
#   'lari'],
# ...
#  ['Sepatu Pria Adidas Marathon GSG TR21 MAN IMPORT anti licin RUNNING KEREN',
#   200000,
#   4.3,
#   'Kab. Tangerang',
#   'Antarez Shop',
#   'lari'],
#  ['Sepatu Spike Sprint Atletik Paku HEALTH 135 BLUE GREEN ORIGINAL',
#   580000,
#   4.5,
#   'Gresik',
#   'sport market',
#   'lari'],
#  ['Sepatu nike airmax pailon | sepatu murah nike adidas specs puma mizuno neo fly',
#   180000,
#   '5',
#   'Kab. Mojokerto',
#   'WILLDANCE',
#   'lari'],
#  ['Bat pingpong DHS 2002', 78500, '5', 'Jakarta Barat', 'Globalsport', 'lari'],
#  ['Mainan tayo READY SELALU bus tayo mobil tayo bis tayo pull back 4 warna harga satuan',
#   9500,
#   4.9,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['SENTER KEPALA SUPER TERANG IMPORT MURAH LUMEN  Bersepeda Memancing Camping Hiking  Berlayar',
#   197000,
#   '5',
#   'Jakarta Pusat',
#   'Grosir Mall',
#   'renang'],
#  ['SENTER KEPALA SUPER TERANG IMPORT MURAH LUMEN MENYARI REPTIL MALAM HARI',
#   97000,
#   '5',
#   'Jakarta Pusat',
#   'Grosir Mall',
#   'renang'],
#  ['PAKET SENTER KEPALA SUPER TERANG HEADLAMP T6 XM-L 5000 LUMENS TERBARU 2020',
#   265200,
#   '5',
#   'Jakarta Pusat',
#   'Grosir Mall',
#   'renang'],
#  ['Promo Dry Bag 5L 10L 20L Ocean Pack',
#   40000,
#   4.9,
#   'Bekasi',
#   'TibaTibaAda',
#   'renang'],
#  ['KOLAM RENANG ANAK KOTAK POLOS BESTWAY UKURAN BESAR 305 CM',
#   465000,
#   '5',
#   'Tangerang',
#   'SYAFAH TOYS',
#   'renang'],
#  ['ABC Pool School Pelampung Rompi Anak Sz M Swim Vest Jaket Ban Renang - Kuning',
#   41900,
#   4.8,
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'renang'],
#  ['padox Karet speargun 10mm tebal per CM karet tembak ikan Spearfishing tombak ikan Diving Scuba padox padok',
#   1500,
#   4.9,
#   'Jakarta Barat',
#   'PADOX Sport',
#   'renang'],
#  ['celana renang speedo polos CRSP01',
#   40000,
#   4.8,
#   'Bekasi',
#   'Kinan Sport',
#   'renang'],
#  ['Baju Renang Anak Laki laki TK Usia 3 - 6 Tahun',
#   65000,
#   4.9,
#   'Tangerang',
#   'Area Sportswear Official',
#   'renang'],
#  ['KACAMATA RENANG MERK SPEEDO - BISA DIPAKAI UNTUK ANAK - ANAK DAN DEWASA ( KUALITAS GOOD )',
#   45000,
#   4.8,
#   'Jakarta Utara',
#   'REC SHOP FERRY',
#   'renang'],
#  ['MOUTHPIECE MOUTH PIECE REGULATOR SNORKEL DIVING SCUBA AMSCUD SILICONE Snorkling',
#   15000,
#   4.9,
#   'Magelang',
#   'WARUNG MAGELANG',
#   'renang'],
#  ['OCT6347 mainan anak edukasi kontruksi isi 6pcs',
#   16000,
#   4.9,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['Bestway 51117 Kolam Renang Anak Karet Pelangi 4 Ring 157cm x 46cm Bestway Rainbow Play Pool',
#   158900,
#   4.9,
#   'Jakarta Barat',
#   'Gudang Olahraga',
#   'renang'],
#  ['INTIME Kolam Baby Spa Kotak 4 Ring - Pool Renang Anak Bayi & Pompa & neck ring',
#   330000,
#   4.8,
#   'Tangerang',
#   'Bobo Baby Shop',
#   'renang'],
#  ['Kacamata renang Dewasa Anti Fog & Uv Protection Ruihe rh9200 Original',
#   50000,
#   4.8,
#   'Depok',
#   'lbagstore',
#   'renang'],
#  ['Kacamata renang speedo 886',
#   79000,
#   4.7,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'renang'],
#  ['Papan Pelampung Renang Swimming Board Papan Renang Anak Image',
#   23900,
#   4.9,
#   'Jakarta Barat',
#   'Hans Toy House',
#   'renang'],
#  ['Kacamata Renang Anak ANTI FOG UV anak remaja dan dewasa',
#   30000,
#   4.8,
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'renang'],
#  ['Kaca mata renang SPEEDO riben',
#   90000,
#   4.7,
#   'Jakarta Timur',
#   'MUTIARA SPORT',
#   'renang'],
#  ['KACAMATA RENANG DEWASA GRILONG ANTI FOG EMBUN FREE PENUTUP TELINGA',
#   45000,
#   4.9,
#   'Jakarta Pusat',
#   'shaleh abdul azis',
#   'renang'],
#  ['JSP 3008 mainan mobil truck pengangkut mobil isi 1',
#   20000,
#   4.8,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['Kacamata Renang Anak Tanggung Feilang 2102',
#   8750,
#   4.8,
#   'Jakarta Utara',
#   'DeMurah',
#   'renang'],
#  ['Clip Klip Penutup Hidung Penyumbat Telinga Renang Diving Speeds Speedo',
#   8300,
#   4.8,
#   'Depok',
#   'lbagstore',
#   'renang'],
#  ['Paling murah.... Kaca mata renang  SPEEDO LX-5000',
#   90000,
#   4.7,
#   'Jakarta Timur',
#   'MUTIARA SPORT',
#   'renang'],
#  ['DRY BAG 5L WATER PROOF BAG TAS ANTI AIR PANTAI OUTDOOR PVC OCEAN PACK - Hitam',
#   46000,
#   4.8,
#   'Jakarta Pusat',
#   'Vapor lab',
#   'renang'],
#  ['ABC Pool School Pelampung Rompi Anak Sz S. Swim Vest Jaket Ban Renang - Biru',
#   28000,
#   4.8,
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'renang'],
#  ['Kacamata Renang Dewasa Feilang 6102 & Tempat',
#   16970,
#   4.6,
#   'Jakarta Utara',
#   'DeMurah',
#   'renang'],
#  ['DRY BAG 20L WATER PROOF BAG TAS ANTI AIR OUTDOOR PANTAI RENANG OCEAN - Hijau',
#   65000,
#   4.8,
#   'Jakarta Pusat',
#   'Vapor lab',
#   'renang'],
#  ['EAR PLUGS TUTUP PENYUMBAT TELINGA',
#   2900,
#   4.8,
#   'Jakarta Utara',
#   'Vannes Store',
#   'renang'],
#  ['Miu Ban Renang Pelampung Murah 60cm',
#   18500,
#   4.8,
#   'Jakarta Utara',
#   'miu miu shop',
#   'renang'],
#  ['Topi Renang Speedo Silicone',
#   18000,
#   4.7,
#   'Jakarta Utara',
#   'All Sporting Goods',
#   'renang'],
#  ['Topi Renang Silikon Elastis Snorkling Diving Flexible Swimming Cap',
#   15000,
#   4.8,
#   'Depok',
#   'LBS OFFICIAL STORE',
#   'renang'],
#  ['senter kepala selam nyelam / headlamp diving',
#   51000,
#   4.3,
#   'Jakarta Utara',
#   'Majualibaba',
#   'renang'],
#  ['Jual 10L DRY BAG WATERPROOF OUTDOOR SHOULDER DUFFLE SACK KAYAK TAS ANTI AIR - Biru Navy',
#   52000,
#   4.8,
#   'Jakarta Pusat',
#   'Vapor lab',
#   'renang'],
#  ['Kacamata Renang Speedo 86S Anti Fog & UV',
#   79000,
#   4.7,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'renang'],
#  ['BAJU RENANG ANAK PEREMPUAN WANITA MUSLIMAH MUSLIM',
#   130000,
#   4.9,
#   'Bekasi',
#   'Na..Za',
#   'renang'],
#  ['ROMPI ATUNAS Size S LIFE JACKET- ROMPI PELAMPUNG MERK ATUNAS UNTUK KE',
#   55000,
#   4.7,
#   'Tangerang',
#   'Yusup Suheri',
#   'renang'],
#  ['Swimming Cap SPEEDO Topi Renang Anak Dewasa - Fuchsia',
#   25996,
#   4.8,
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'renang'],
#  ['Mainan mobil mobilan truck isi lego',
#   40000,
#   4.9,
#   'Jakarta Timur',
#   'Amaliyah Online Shop',
#   'renang'],
#  ['Bestway Rectangular Pool Biru Putih 2.01m. Kolam Renang Karet Anak - Hijau Jakarta',
#   260896,
#   4.9,
#   'Jakarta Pusat',
#   'Sportsite Official',
#   'renang'],
#  ['ROMPI ATUNAS Size M LIFE JACKET - ROMPI PELAMPUNG MERK ATUNAS',
#   65000,
#   4.8,
#   'Tangerang',
#   'Yusup Suheri',
#   'renang'],
#  ['ST 2082 mainan anak mobil truck pengangkut 2 mobil kontruksi tidak gandeng mobil truck mainan',
#   23750,
#   4.8,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['Bestway 51008 Kolam Renang Anak Coral Kids Pool 102cm x 25cm mandi bola',
#   67900,
#   '5',
#   'Depok',
#   'pandawa grosir',
#   'renang'],
#  ['Jual 6-10 th Ban Lengan Anak Intex Polos Ban Tangan Pelampung',
#   32500,
#   4.8,
#   'Jakarta Utara',
#   'odettes',
#   'renang'],
#  ['SIZE S - LIFE JACKET/ROMPI PELAMPUNG MERK ATUNAS UNTUK KESELAMATAN OLAHRAGA AIR-MURAH BANGET',
#   50000,
#   4.6,
#   'Jakarta Utara',
#   'REC SHOP FERRY',
#   'renang'],
#  ['celana renang panjang sebetis dewasa speedo CRP78',
#   59000,
#   4.8,
#   'Bekasi',
#   'Kinan Sport',
#   'renang'],
#  ['Kolam renang anak bestway 51009 ukuran 122 x 25 cm dan POMPA LISTRIK',
#   133000,
#   '5',
#   'Depok',
#   'pandawa grosir',
#   'renang'],
#  ['Kacamata Renang Speeds LX5100 Built-In Earplug',
#   55000,
#   4.7,
#   'Jakarta Selatan',
#   'Duta Sport',
#   'renang'],
#  ['Terusi - Copper Sulfate 1 kg - Pembiru Anti Lumut Kolam Renang',
#   51900,
#   4.8,
#   'Jakarta Barat',
#   'Rendys',
#   'renang'],
#  ['Topi renang swimming cap speedo',
#   20000,
#   4.6,
#   'Jakarta Utara',
#   'odettes',
#   'renang'],
#  ['PAPAN PELAMPUNG RENANG SKILL PAPAN SELUNCUR TEBAL SWIMMING BOARD',
#   32500,
#   4.8,
#   'Jakarta Pusat',
#   'shaleh abdul azis',
#   'renang'],
#  ['Bestway 54006 Kolam Renang Anak 262x175x51 Kolam Anak',
#   325000,
#   '5',
#   'Depok',
#   'pandawa grosir',
#   'renang'],
#  ['celana renang panjang speedo CSPP06',
#   65000,
#   4.9,
#   'Bekasi',
#   'Kinan Sport',
#   'renang'],
#  ['celana renang jumbo speedo polos CRJP04',
#   49000,
#   4.8,
#   'Bekasi',
#   'Kinan Sport',
#   'renang'],
#  ['Baju Renang Muslimah Dewasa Motif Cantik',
#   115000,
#   4.8,
#   'Jakarta Timur',
#   'Itos Olshop',
#   'renang'],
#  ['baju renang diving pria dewasa laki dewasa setelan',
#   134325,
#   4.9,
#   'Tangerang',
#   'Area Sports',
#   'renang'],
#  ['Kacamata Renang Minus (Miopi) Profesional Anti Embun (Fogging)',
#   68500,
#   4.8,
#   'Bandung',
#   'Abdurrahman Store',
#   'renang'],
#  ['Kolam Renang Anak / Kolam Renang Intex',
#   79000,
#   4.7,
#   'Jakarta Utara',
#   'SallyShops',
#   'renang'],
#  ['kacamata renang speedo',
#   45000,
#   4.7,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'renang'],
#  ['Kolam renang anak bestway 51009 ukuran 122 x 25 cm dan POMPA MANUAL',
#   123000,
#   '5',
#   'Depok',
#   'pandawa grosir',
#   'renang'],
#  ['Ban Pelampung Lengan Anak Ban Tangan Anak Intex Frozen',
#   35000,
#   4.9,
#   'Jakarta Utara',
#   'odettes',
#   'renang'],
#  ['Swimming Kickboard Papan Luncur Anak Belajar Renang Seluncur IM-608',
#   23900,
#   4.9,
#   'Jakarta Utara',
#   'Toys for Fun',
#   'renang'],
#  ['CAP / TUTUP KEPALA RENANG MERK SPEEDO ( TERBUAT  BAHAN KARET ) - UNTUK DEWASA',
#   19000,
#   4.8,
#   'Jakarta Utara',
#   'REC SHOP FERRY',
#   'renang'],
#  ['Kacamata Renang Anak / Kaca Mata Renang',
#   12900,
#   '4',
#   'Bandung',
#   'elektroniku',
#   'renang'],
#  ['Miumiu Kolam Renang anak/ Bak Mandi - Bathtub Anak - 102 cm',
#   73500,
#   4.8,
#   'Jakarta Utara',
#   'miu miu shop',
#   'renang'],
#  ['Kacamata Renang Anti Fog & UV Mirror Earplug Riben kilap Dewasa SPEEDO -866',
#   59250,
#   4.7,
#   'Jakarta Barat',
#   'juragan olahraga',
#   'renang'],
#  ['Mobil Pemadam fire resque RKC 02056-1',
#   16500,
#   4.8,
#   'Jakarta Timur',
#   'Amaliyah Online Shop',
#   'renang'],
#  ['spearfising rubber band 14mm perCM Karet tembak panah ikan Karet speargun diving padox katapel padok',
#   2000,
#   4.2,
#   'Jakarta Barat',
#   'PADOX Sport',
#   'renang'],
#  ['Penutup|Pelindung|Tutup|Telinga|Kuping|Ear Plugs|Remaja|Dewasa|Anak|Anti|Redam|Peredam|Air|Bising|Gaduh|Ribut|Suara|Macks|EarPlugs',
#   80000,
#   4.7,
#   'Jakarta Pusat',
#   'Dewei Babyshop',
#   'renang'],
#  ['ST 2081 mainan anak mobil mobilan truck pengangkut 2 mobil tidak gandeng mobil truck mainan',
#   21750,
#   4.9,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['KACAMATA RENANG ANTIFOG MURAH - SWIMMING GOGGLES',
#   28000,
#   4.8,
#   'Bekasi',
#   'HANZ ONLINE STORE',
#   'renang'],
#  ['Intime YT 011 Kolam Renang Anak 262x175x51 Kolam Anak',
#   305000,
#   4.7,
#   'Depok',
#   'pandawa grosir',
#   'renang'],
#  ['dry bag Travel Bag drybag 10 L PVC anti air waterproof not consina',
#   53000,
#   4.9,
#   'Jakarta Barat',
#   'Pasar Gelap',
#   'renang'],
#  ['Celana Renang Speedo',
#   60000,
#   4.6,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'renang'],
#  ['Baju renang anak polos cowok cewek 0-6 tahun',
#   60000,
#   4.8,
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'renang'],
#  ['SWIMSUIT BAJU RENANG ANAK PEREMPUAN MUSLIMAH MUSLIM BENS ORIGINAL',
#   130000,
#   4.7,
#   'Bekasi',
#   'Manto toys',
#   'renang'],
#  ['Kaporit 90Persen - 1 KG - Kaporit Granular 90Persen - Filter Air - Pembersih Air - Pembersih Kolam Renang - Anti Bakteri',
#   70000,
#   4.9,
#   'Jakarta Barat',
#   'KimiaID',
#   'renang'],
#  ['Kolam Renang Anak Bestway 51008 Uk 102cm X 25cm',
#   69000,
#   4.9,
#   'Jakarta Utara',
#   'ZONA MAINAN OFFICIAL',
#   'renang'],
#  ['LU 1 Ready stock Tamiya mini 4WD murahh menggunakan baterai terbaru bonus 4 ban roda busa',
#   15750,
#   4.8,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['Size L Baju renang wanita muslimah syari',
#   245000,
#   4.9,
#   'Bekasi',
#   'Amany Store',
#   'renang'],
#  ['Kacamata renang Dewasa Anti Fog &amp Uv Protection Ruihe rh9200 Original - Biru',
#   45000,
#   4.8,
#   'Depok',
#   'lbagstore',
#   'renang'],
#  ['Pompa Angin Injak Bestway',
#   25500,
#   4.8,
#   'Jakarta Utara',
#   'miu miu shop',
#   'renang'],
#  ['celana renang pria speedo',
#   45000,
#   4.5,
#   'Jakarta Barat',
#   'ids sport',
#   'renang'],
#  ['Pelampung Rompi Puddle Jumper - Yellow Bee',
#   329000,
#   4.9,
#   'Jakarta Selatan',
#   'kiddie splash official',
#   'renang'],
#  ['topi renang speedo', 17500, 4.8, 'Jakarta Barat', 'ids sport', 'renang'],
#  ['Pakaian Renang Anak Laki Laki 0-5 Tahun Cewe Cowo diving balita Polos Tersedisa Lapisan sleting',
#   60000,
#   'no rating',
#   'Tangerang Selatan',
#   'CV. Nitis berkah',
#   'renang'],
#  ['TERMURAH kolam renang anak bestway best way 51008 original asli bagus murah bisa gojek',
#   59000,
#   4.9,
#   'Jakarta Barat',
#   'kepob',
#   'renang'],
#  ['Kacamata Renang Antifog Water World Swim Goggle DZ1600',
#   16990,
#   4.9,
#   'Jakarta Utara',
#   'DeMurah',
#   'renang'],
#  ['Celana Renang SHARK JUMBO Original size XXXL',
#   69500,
#   4.8,
#   'Jakarta Timur',
#   'MUTIARA SPORT',
#   'renang'],
#  ['Kacamata Renang Anak INTEX Play Goggles 55602 Aquaflow Berenang',
#   19500,
#   4.8,
#   'Jakarta Barat',
#   'Mister Murah Ofc',
#   'renang'],
#  ['Promo Premium Drybag Rangsel 25L Waterproof',
#   185500,
#   4.9,
#   'Bekasi',
#   'TibaTibaAda',
#   'renang'],
#  ['Paket celana renang speedo+kacamata renang speedo LX+topi renang speedo',
#   150000,
#   4.5,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'renang'],
#  ['Sepatu Pantai Aqua Diving Socks Beach Shoes Renang Kaos Kaki Air - XXL hitam',
#   30000,
#   4.8,
#   'Depok',
#   'lbagstore',
#   'renang'],
#  ['Intex - Kolam Renang Pelangi Anak - Kolam mandi Bola Anak',
#   95000,
#   4.7,
#   'Jakarta Utara',
#   'odettes',
#   'renang'],
#  ['Mainan Kereta 3 Gerbong',
#   25000,
#   4.7,
#   'Jakarta Timur',
#   'Amaliyah Online Shop',
#   'renang'],
#  ['Kolam Renang Anak Kotak Polos Bestway',
#   402300,
#   4.7,
#   'Tangerang',
#   'theona tata',
#   'renang'],
#  ['Baju Renang Muslim Anak ML TG P.',
#   185000,
#   4.9,
#   'Tangerang Selatan',
#   'Asyifameccashop LITA AD',
#   'renang'],
#  ['Mainan mobil sport ferari star rider super racing PULL BACK',
#   7500,
#   4.9,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['Celana Renang Speedo Dewasa',
#   40000,
#   4.7,
#   'Jakarta Utara',
#   'odettes',
#   'renang'],
#  ['Bestway 54006 Kolam Renang Karet Anak Keluarga Besar 262 cm - Kolam Plus Pompa Listrik',
#   354900,
#   '5',
#   'Jakarta Barat',
#   'Gudang Olahraga',
#   'renang'],
#  ['Kacamata Renang Speedo S-86 / Kacamata Renang Speedo Dewasa',
#   60000,
#   4.5,
#   'Jakarta Utara',
#   'odettes',
#   'renang'],
#  ['ROMPI ATUNAS Size L LIFE JACKET ROMPI PELAMPUNG MERK ATUNAS',
#   75000,
#   4.7,
#   'Tangerang',
#   'Yusup Suheri',
#   'renang'],
#  ['mainan damkar HKR isi 1pcs mainan anak edukasi mobil pemadam kebakaran isi 1pcs Pull back',
#   8750,
#   4.9,
#   'Malang',
#   'kevin toys malang',
#   'renang'],
#  ['Kimono Handuk',
#   290000,
#   4.7,
#   'Kab. Bandung',
#   'Lans Kimono Handuk',
#   'renang'],
#  ['ROMPI ATUNAS Size S LIFE JACKET ROMPI PELAMPUNG MERK ATUNAS',
#   55000,
#   4.6,
#   'Tangerang',
#   'Yusup Suheri',
#   'renang'],
#  ['Set Kolam Renang Intex / Kolam Renang Anak Intex',
#   130000,
#   4.7,
#   'Jakarta Utara',
#   'SallyShops',
#   'renang'],
#  ['Kolam renang anak intex original kolam karet  147cm x 33cm',
#   170000,
#   4.7,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'renang'],
#  ['Kaca mata renang SPEEDO SF-988',
#   29500,
#   4.7,
#   'Jakarta Timur',
#   'MUTIARA SPORT',
#   'renang'],
#  ['Kacamata Renang Speedo Dewasa / Kacamata Renang Anti Fog Anti Uv Murah',
#   25000,
#   4.4,
#   'Jakarta Utara',
#   'odettes',
#   'renang'],
#  ['Baju Renang Anak Perempuan TK 3 - 6 Tahun',
#   65000,
#   4.8,
#   'Tangerang',
#   'Area Sportswear Official',
#   'renang'],
#  ['Papan Luncur Anak Belajar Renang Seluncur Pelampung - PEREMPUAN',
#   45500,
#   4.8,
#   'Jakarta Selatan',
#   'Berkah toys',
#   'renang'],
#  ['Ban Pelampung Leher Bayi / Neck Ring For Baby',
#   40000,
#   4.6,
#   'Jakarta Utara',
#   'SallyShops',
#   'renang'],
#  ['Terlaris Pompa Bulat . Pompa Ban Renang',
#   53000,
#   '5',
#   'Jakarta Pusat',
#   'Hommies',
#   'renang'],
#  ['Pelampung / Ban Berenang Anak Step B / Swim Vest / Rompi Renang',
#   28500,
#   4.7,
#   'Tangerang',
#   'theona tata',
#   'renang'],
#  ['Mainan Mobil Truck Pengangkut Mobil Mika Heavy Truck',
#   30000,
#   4.8,
#   'Jakarta Timur',
#   'Amaliyah Online Shop',
#   'renang'],
#  ['ban renang bulat polkadot termurah swim ring tube pelampung anak murah',
#   17100,
#   4.4,
#   'Surabaya',
#   'toysretail',
#   'renang'],
#  ['Kasur INTEX floating mat matras air pelampung kolam renang 59703',
#   80000,
#   4.6,
#   'Jakarta Selatan',
#   'Gema Sports',
#   'renang'],
#  ['Baju Renang Anak Laki-laki Polos TK Selam Anak Panjang',
#   95000,
#   4.9,
#   'Tangerang',
#   'Area Sportswear Official',
#   'renang'],
#  ['STEP A Rompi pelampung renang anak Swim Vest',
#   30800,
#   4.8,
#   'Tangerang',
#   'theona tata',
#   'renang'],
#  ...]

# %%
#5. Data Storing

#prepare the container
product_name, product_category, product_rating, store_name, price = [],[],[],[],[]

#filling the container
for item in products_cleaned:
    product_name.append(item[0]) #adding the product name in the index of 0 from the beginning
    product_category.append(item[-1]) #adding the product category name in the index of 1 from behind
    product_rating.append(item[2]) #adding the product rating in the index of 2 from the beginning
    store_name.append(item[-2]) #adding the product name in the index of 2 from behind
    price.append(item[1]) #adding the product name in the index of 1 from the beginning
    
#zipping the lists into dictionary
listCols = ['product_name', 'product_category', 'product_rating', 'store_name', 'price']
dict_data = dict(zip(
            listCols,
                    (product_name, 
                     product_category, 
                     product_rating, 
                     store_name, 
                     price)
))

#saving the dataframe into csv
df = pd.DataFrame(data = dict_data)
df.to_csv('scraped_data.csv', index=False)

# %% [markdown]
# ### This is the end of the project.
#
# Thank you for your attention.
# <br>
# <br>
# <br>
# <br>
# <br>
# *below is some experiments I used for this project. you can check this out of you're interested about my trial and error. Thank you.

# %%
#It was used to check on the structure of the data

'''
sembilan = 0
sepuluh = 0
sebelas = 0
duabelas = 0
lebih = 0
lima = 0
enam = 0
tujuh = 0
delapan = 0
for product in products_cleaned :
    if len(product) <= 6 :
        enam+=1
    elif len(product) == 7:
        tujuh +=1
    elif len(product) == 8:
        delapan +=1
    elif len(product) == 9 :
        sembilan +=1
    elif len(product) == 10:
        sepuluh +=1
    elif len(product) == 11:
        sebelas +=1
    elif len(product) == 12:
        duabelas +=1
    else:
        lebih+=1#print(len(product))
        
print(enam, tujuh, delapan, sembilan, sepuluh, sebelas, duabelas, lebih)
enam+tujuh+delapan+sembilan+sepuluh+sebelas+duabelas+lebih
'''
# Out:
# 3880 0 0 0 0 0 0 0
# 3880

# %%
#this one for exploring the data for cleaning too
enam = []
tujuh = []
delapan = []
for product in products_cleaned :
    if len(product) <= 6 :
        enam.append(product)
    elif len(product) == 7:
        tujuh.append(product)
    elif len(product) == 8:
        delapan.append(product)
    elif len(product) == 9 :
        sembilan.append(product)
    elif len(product) == 10:
        sepuluh.append(product)
        
print(enam[0])
# Out:
# ['Tissue Handuk Mini Permen Travelling Liburan Kompress Towel Portable', 'Rp600', '4.9', 'Depok', 'LBS OFFICIAL STORE', 'lari']

# %%
#it was used to check for the abnormality
lah_tes = 0
for product in products_cleaned :
    if len(product) == 7 :
        pisah = product[2].split("Terjual")
        if pisah[0] == '':
            jumlah_tes+=1
        else:
            print(product)
jumlah_tes
# Out:
# ['Besst seller sepatu tenis reebok', 'Grosir', 'Rp295.000', 'Bandung Barat', 'ADRS FOOTWEAR PROJECT', '8rb Feedback Positif', 'tenis']
# ['Raket Badminton Tanggung Baby Racket By Classic 2 Pcs', 'Grosir', 'Rp75.000', 'Depok', 'ABB Family', '11rb Feedback Positif', 'tenis']
# ['celana tenis-celana pingpong-celana murah-celana joging stiga gold peria dan wanita', 'Grosir', 'Rp75.000', 'Jember', 'IMPORTIR JERSEY  FUTSAL', '5rb Feedback Positif', 'tenis']
# ['GROSIR Raket Tenis Carbon Aluminium Alloy', 'Grosir', 'Rp224.000', 'Jakarta Barat', 'Ogah Repot', '21rb Feedback Positif', 'tenis']
# 42

# %%
#it was used to check on the minimum quantity for the data needed
renang = 0
tenis = 0
lari = 0
badminton = 0
pancing = 0
for product in products:
    if product[-1] == 'renang':
        renang+=1
    elif product[-1] == 'tenis':
        tenis += 1 
    elif product[-1] == 'badminton' :
        badminton += 1
    elif product[-1] == 'lari' :
        lari += 1
    else:
        pancing +=1
print('renang:', renang, 'lari:', lari, 'badminton:', badminton, 'tenis:', tenis, 'pancing:',pancing)
# Out:
# renang: 840 lari: 880 badminton: 800 tenis: 740 pancing: 620

# %%
#Alternative
'''
This is my lines of codes for scraping with Selenium Pagination, unfortunately, it doesn't work.
So I'm using my code above for pagination using link address.

#Running WebDriver
driver.get(website_adress)
wait = driver.implicitly_wait(10)
wait
#driver.implicitly_wait(10)
cursor = driver.find_element(By.LINK_TEXT, "Kategori barang")
cursor.click()

wait
#driver.implicitly_wait(10)
cursor = driver.find_element(By.LINK_TEXT, "Olahraga")
cursor.click()

wait
#driver.implicitly_wait(10)
driver.execute_script("window.scrollTo(0, 700)")

kategori = ['Lari', 'Badminton', 'Renang', 'Pancing', 'Tenis']
for i in kategori:
    wait
    #driver.implicitly_wait(10)
    cursor = driver.find_element(By.LINK_TEXT, i)
    cursor.click()
    
    #for j < 20:
     #   wait
      #  driver.execute_script("window.scrollTo(0, 6000)")
       # wait
        ##driver.implicitly_wait(30)
        #(driver.find_element_by_link_text(str(j+2))).click()
        #j+=1
    wait    
    #driver.implicitly_wait(30)
    driver.execute_script("window.scrollTo(0, 100)")
    cursor2 = driver.find_element(By.LINK_TEXT, "Olahraga")
    cursor2.click()
driver.quit()
#a.click()
#close welcome screen shopee
'''
